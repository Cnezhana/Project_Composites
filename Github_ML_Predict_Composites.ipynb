# %% [markdown]
# # **Прогнозирование целевой переменной "Прочность при растяжении"**

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1023 entries, 0 to 1022
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Соотношение_матрица_наполнитель  1023 non-null   float64
#  1   Плотность                        1023 non-null   float64
#  2   Модуль_упругости                 1023 non-null   float64
#  3   Количество_отвердителя           1023 non-null   float64
#  4   Содержание_эпоксидных_групп      1023 non-null   float64
#  5   Температура_вспышки              1023 non-null   float64
#  6   Поверхностная_плотность          1023 non-null   float64
#  7   Модуль_упругости_при_растяжении  1023 non-null   float64
#  8   Прочность_при_растяжении         1023 non-null   float64
#  9   Потребление_смолы                1023 non-null   float64
#  10  Угол_нашивки                     1023 non-null   int64
# ...

# %% [markdown]
# ## **Модель R2 score train: 0.953,	R2 score test: 0.939, тюнинг модели R2 score test: 0.951**

# %%
pred_model_etr_train = model_etr.predict(X_train)
pred_model_etr = model_etr.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии без гиперпараметров:'+'\033[0m')

print("\tMAE train:", mean_absolute_error(y_train, pred_model_etr_train))
print("\tR2 score train:", r2_score(y_train, pred_model_etr_train))
print("\tcv score train:", cross_val_score(model_etr, X_train, y_train, cv=10).mean())

print("\tMAE test:", mean_absolute_error(y_test, pred_model_etr))
print("\tR2 score test:", r2_score(y_test, pred_model_etr))
# Out:
# ****************************************************
#  Отчет по ререссии без гиперпараметров:
# ****************************************************
# 	MAE train: 35.34249653791304
# 	R2 score train: 0.9531863146097134
# 	cv score train: 0.9040979983232761
# ****************************************************
# 	MAE test: 49.727854665119075
# 	R2 score test: 0.9385956822732784

# %%
model_etr_rs = grid_etr.best_estimator_
model_etr_rs.fit(X_train, y_train)
pred_model_etr_rs = model_etr_rs.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии GridSearchCV:'+'\033[0m')

print("\tMAE:", mean_absolute_error(y_test, pred_model_etr_rs))
print("\tR2 score:", r2_score(y_test, pred_model_etr_rs))
# Out:
# ****************************************************
#  Отчет по ререссии GridSearchCV:
# ****************************************************
# 	MAE: 35.10727518633356
# 	R2 score: 0.950995007459576

# %%
# Out:
# Text(0.0, 1.0, 'Сравнение фактических и прогнозных значений модели GridSearchCV')

# %%
result_1
# Out:
#      predicted target  target  error
# 0             2426.05 2436.78  10.73
# 1             2554.97 2553.54  -1.43
# 2             2663.21 2655.70  -7.52
# 3             2455.45 2460.08   4.63
# 4             3007.74 2980.20 -27.54
# ..                ...     ...    ...
# 295           3057.42 3056.65  -0.77
# 296           2388.09 2403.96  15.87
# 297           2585.19 2556.03 -29.16
# 298           2530.89 2481.25 -49.64
# 299           2389.47 2397.21   7.74
#
# [300 rows x 3 columns]

# %% [markdown]
# ## **Модель R2 score train: 1.0,	R2 score test: 0.847 тюнинг модели R2 score test: 0.857**

# %%
pred_model_etr_train = model_etr.predict(X_train)
pred_model_etr = model_etr.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии без гиперпараметров:'+'\033[0m')

print("\tMAE train:", mean_absolute_error(y_train, pred_model_etr_train))
print("\tR2 score train:", r2_score(y_train, pred_model_etr_train))
print("\tcv score train:", cross_val_score(model_etr, X_train, y_train, cv=10).mean())

print("\tMAE test:", mean_absolute_error(y_test, pred_model_etr))
print("\tR2 score test:", r2_score(y_test, pred_model_etr))
# Out:
# ****************************************************
#  Отчет по ререссии без гиперпараметров:
# ****************************************************
# 	MAE train: 2.9300965777401495e-12
# 	R2 score train: 1.0
# 	cv score train: 0.8664644961868602
# ****************************************************
# 	MAE test: 115.29850785591898
# 	R2 score test: 0.8473414845438676

# %%
model_etr_rs = grid_etr.best_estimator_
model_etr_rs.fit(X_train, y_train)
pred_model_etr_rs = model_etr_rs.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии GridSearchCV:'+'\033[0m')

print("\tMAE:", mean_absolute_error(y_test, pred_model_etr_rs))
print("\tR2 score:", r2_score(y_test, pred_model_etr_rs))
# Out:
# ****************************************************
#  Отчет по ререссии GridSearchCV:
# ****************************************************
# 	MAE: 112.70040201454205
# 	R2 score: 0.8573615696692247

# %%
# Out:
# Text(0.0, 1.0, 'Сравнение фактических и прогнозных значений модели GridSearchCV')

# %%
result_2
# Out:
#      predicted target  target   error
# 0             2420.64 2436.78   16.14
# 1             2502.50 2553.54   51.04
# 2             2557.15 2655.70   98.55
# 3             2439.35 2460.08   20.73
# 4             2902.65 2980.20   77.54
# ..                ...     ...     ...
# 295           2963.78 3056.65   92.86
# 296           2370.88 2403.96   33.08
# 297           2636.72 2556.03  -80.69
# 298           2584.56 2481.25 -103.30
# 299           2390.78 2397.21    6.44
#
# [300 rows x 3 columns]

# %% [markdown]
# # **Прогнозирование целевой переменной "Модуль упругости при растяжении"**

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1023 entries, 0 to 1022
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Соотношение_матрица_наполнитель  1023 non-null   float64
#  1   Плотность                        1023 non-null   float64
#  2   Модуль_упругости                 1023 non-null   float64
#  3   Количество_отвердителя           1023 non-null   float64
#  4   Содержание_эпоксидных_групп      1023 non-null   float64
#  5   Температура_вспышки              1023 non-null   float64
#  6   Поверхностная_плотность          1023 non-null   float64
#  7   Модуль_упругости_при_растяжении  1023 non-null   float64
#  8   Прочность_при_растяжении         1023 non-null   float64
#  9   Потребление_смолы                1023 non-null   float64
#  10  Угол_нашивки                     1023 non-null   int64
# ...

# %% [markdown]
# ## **Модель R2 score train: 0.933,	R2 score test: 0.868, тюнинг модели R2 score test: 0.897**

# %%
pred_model_etr_train = model_etr.predict(X_train)
pred_model_etr = model_etr.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии без гиперпараметров:'+'\033[0m')

print("\tMAE train:", mean_absolute_error(y_train, pred_model_etr_train))
print("\tR2 score train:", r2_score(y_train, pred_model_etr_train))
print("\tcv score train:", cross_val_score(model_etr, X_train, y_train, cv=10).mean())

print("\tMAE test:", mean_absolute_error(y_test, pred_model_etr))
print("\tR2 score test:", r2_score(y_test, pred_model_etr))
# Out:
#  Отчет по ререссии без гиперпараметров:
# 	MAE train: 0.4391583918165254
# 	R2 score train: 0.9331576207794032
# 	cv score train: 0.8675910249671102
# 	MAE test: 0.6120063314119477
# 	R2 score test: 0.867682341007791

# %%
model_etr_rs = grid_etr.best_estimator_
model_etr_rs.fit(X_train, y_train)
pred_model_etr_rs = model_etr_rs.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии GridSearchCV:'+'\033[0m')

print("\tMAE:", mean_absolute_error(y_test, pred_model_etr_rs))
print("\tR2 score:", r2_score(y_test, pred_model_etr_rs))
# Out:
#  Отчет по ререссии GridSearchCV:
# 	MAE: 0.49026788913554875
# 	R2 score: 0.8964883897521589

# %%
# Out:
# Text(0.0, 1.0, 'Сравнение фактических и прогнозных значений модели GridSearchCV')

# %%
result_3
# Out:
#      predicted target  target  error
# 0               76.47   75.27  -1.20
# 1               73.48   73.45  -0.03
# 2               73.22   75.18   1.96
# 3               75.07   74.79  -0.28
# 4               70.85   71.04   0.18
# ..                ...     ...    ...
# 295             77.90   77.68  -0.22
# 296             72.31   74.11   1.80
# 297             74.97   75.49   0.51
# 298             74.78   74.61  -0.17
# 299             71.46   74.22   2.76
#
# [300 rows x 3 columns]

# %% [markdown]
# ## **Модель R2 score train: 1.0,	R2 score test: 0.880 тюнинг модели R2 score test: 0.884**

# %%
pred_model_etr_train = model_etr.predict(X_train)
pred_model_etr = model_etr.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии без гиперпараметров:'+'\033[0m')

print("\tMAE train:", mean_absolute_error(y_train, pred_model_etr_train))
print("\tR2 score train:", r2_score(y_train, pred_model_etr_train))
print("\tcv score train:", cross_val_score(model_etr, X_train, y_train, cv=10).mean())

print("\tMAE test:", mean_absolute_error(y_test, pred_model_etr))
print("\tR2 score test:", r2_score(y_test, pred_model_etr))
# Out:
#  Отчет по ререссии без гиперпараметров:
# 	MAE train: 1.0081649146666246e-13
# 	R2 score train: 1.0
# 	cv score train: 0.8868130843050503
# 	MAE test: 0.6035699024842358
# 	R2 score test: 0.879806190983915

# %%
model_etr_rs = grid_etr.best_estimator_
model_etr_rs.fit(X_train, y_train)
pred_model_etr_rs = model_etr_rs.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии GridSearchCV:'+'\033[0m')

print("\tMAE:", mean_absolute_error(y_test, pred_model_etr_rs))
print("\tR2 score:", r2_score(y_test, pred_model_etr_rs))
# Out:
#  Отчет по ререссии GridSearchCV:
# 	MAE: 0.606088915983944
# 	R2 score: 0.8833820627382071

# %%
# Out:
# Text(0.0, 1.0, 'Сравнение фактических и прогнозных значений модели GridSearchCV')

# %%
result_4
# Out:
#      predicted target  target  error
# 0               75.23   75.27   0.04
# 1               73.31   73.45   0.14
# 2               74.10   75.18   1.09
# 3               74.62   74.79   0.18
# 4               71.90   71.04  -0.86
# ..                ...     ...    ...
# 295             77.24   77.68   0.43
# 296             73.41   74.11   0.70
# 297             74.03   75.49   1.46
# 298             74.73   74.61  -0.12
# 299             73.06   74.22   1.16
#
# [300 rows x 3 columns]

# %% [markdown]
# # **Прогнозирование целевой переменной "Соотношение матрица наполнитель"**

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1023 entries, 0 to 1022
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Соотношение_матрица_наполнитель  1023 non-null   float64
#  1   Плотность                        1023 non-null   float64
#  2   Модуль_упругости                 1023 non-null   float64
#  3   Количество_отвердителя           1023 non-null   float64
#  4   Содержание_эпоксидных_групп      1023 non-null   float64
#  5   Температура_вспышки              1023 non-null   float64
#  6   Поверхностная_плотность          1023 non-null   float64
#  7   Модуль_упругости_при_растяжении  1023 non-null   float64
#  8   Прочность_при_растяжении         1023 non-null   float64
#  9   Потребление_смолы                1023 non-null   float64
#  10  Угол_нашивки                     1023 non-null   int64
# ...

# %% [markdown]
# ## **Модель R2 score train: 0.930, R2 score test: 0.844, тюнинг модели R2 score test: 0.885**

# %%
pred_model_etr_train = model_etr.predict(X_train)
pred_model_etr = model_etr.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии без гиперпараметров:'+'\033[0m')

print("\tMAE train:", mean_absolute_error(y_train, pred_model_etr_train))
print("\tR2 score train:", r2_score(y_train, pred_model_etr_train))
print("\tcv score train:", cross_val_score(model_etr, X_train, y_train, cv=10).mean())

print("\tMAE test:", mean_absolute_error(y_test, pred_model_etr))
print("\tR2 score test:", r2_score(y_test, pred_model_etr))
# Out:
#  Отчет по ререссии без гиперпараметров:
# 	MAE train: 0.13051599765087551
# 	R2 score train: 0.930020963477575
# 	cv score train: 0.8659420989074714
# 	MAE test: 0.19618825005637283
# 	R2 score test: 0.8436122103688908

# %%
model_etr_rs = grid_etr.best_estimator_
model_etr_rs.fit(X_train, y_train)
pred_model_etr_rs = model_etr_rs.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии GridSearchCV:'+'\033[0m')

print("\tMAE:", mean_absolute_error(y_test, pred_model_etr_rs))
print("\tR2 score:", r2_score(y_test, pred_model_etr_rs))
# Out:
#  Отчет по ререссии GridSearchCV:
# 	MAE: 0.16292906888442885
# 	R2 score: 0.8852351916059865

# %%
# Out:
# Text(0.0, 1.0, 'Сравнение фактических и прогнозных значений модели GridSearchCV')

# %%
result_5
# Out:
#      predicted target  target  error
# 0                4.28    4.21  -0.07
# 1                3.21    3.16  -0.04
# 2                2.65    2.59  -0.05
# 3                3.07    3.40   0.33
# 4                2.44    2.42  -0.02
# ..                ...     ...    ...
# 295              3.73    3.80   0.08
# 296              2.76    2.78   0.02
# 297              3.02    3.02   0.00
# 298              2.77    2.76  -0.00
# 299              1.70    1.78   0.08
#
# [300 rows x 3 columns]

# %% [markdown]
# ## **Модель R2 score train: 1.0,	R2 score test: 0.870**

# %%
pred_model_etr_train = model_etr.predict(X_train)
pred_model_etr = model_etr.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии без гиперпараметров:'+'\033[0m')

print("\tMAE train:", mean_absolute_error(y_train, pred_model_etr_train))
print("\tR2 score train:", r2_score(y_train, pred_model_etr_train))
print("\tcv score train:", cross_val_score(model_etr, X_train, y_train, cv=10).mean())

print("\tMAE test:", mean_absolute_error(y_test, pred_model_etr))
print("\tR2 score test:", r2_score(y_test, pred_model_etr))
# Out:
#  Отчет по ререссии без гиперпараметров:
# 	MAE train: 3.4316306955272068e-15
# 	R2 score train: 1.0
# 	cv score train: 0.8979902369711151
# 	MAE test: 0.2113864121284256
# 	R2 score test: 0.8695857498810721

# %%
model_etr_rs = grid_etr.best_estimator_
model_etr_rs.fit(X_train, y_train)
pred_model_etr_rs = model_etr_rs.predict(X_test)

print('\033[91m\033[1m'+' Отчет по ререссии GridSearchCV:'+'\033[0m')

print("\tMAE:", mean_absolute_error(y_test, pred_model_etr_rs))
print("\tR2 score:", r2_score(y_test, pred_model_etr_rs))
# Out:
#  Отчет по ререссии GridSearchCV:
# 	MAE: 0.21608484191847255
# 	R2 score: 0.8664863541816356

# %%
# Out:
# Text(0.0, 1.0, 'Сравнение фактических и прогнозных значений модели GridSearchCV')

# %%
result_6
# Out:
#      predicted target  target  error
# 0                4.02    4.21   0.19
# 1                3.12    3.16   0.04
# 2                2.75    2.59  -0.16
# 3                2.93    3.40   0.47
# 4                2.53    2.42  -0.11
# ..                ...     ...    ...
# 295              3.62    3.80   0.18
# 296              2.75    2.78   0.03
# 297              3.01    3.02   0.01
# 298              2.79    2.76  -0.03
# 299              2.03    1.78  -0.25
#
# [300 rows x 3 columns]

# %% [markdown]
# # **Итоги и результаты прогнозирования по другим моделям и целевым переменным**

# %%
# Out:
# <style type="text/css">
# #T_85023_row0_col2 {
#   background-color: #f6b38d;
#   color: #000000;
# }
# #T_85023_row0_col3 {
#   background-color: #f7ccaf;
#   color: #000000;
# }
# #T_85023_row0_col4, #T_85023_row0_col5, #T_85023_row1_col4, #T_85023_row1_col5, #T_85023_row2_col4, #T_85023_row2_col5, #T_85023_row5_col4, #T_85023_row5_col5 {
#   background-color: #3f1b43;
#   color: #f1f1f1;
# }
# #T_85023_row1_col2 {
#   background-color: #f7caac;
#   color: #000000;
# }
# #T_85023_row1_col3, #T_85023_row6_col2, #T_85023_row7_col4, #T_85023_row7_col5 {
#   background-color: #faebdd;
#   color: #000000;
# }
# #T_85023_row2_col2 {
#   background-color: #f58860;
#   color: #f1f1f1;
# }
# #T_85023_row2_col3 {
#   background-color: #f6b691;
#   color: #000000;
# }
# #T_85023_row3_col2 {
#   background-color: #f3714d;
#   color: #f1f1f1;
# }
# #T_85023_row3_col3 {
#   background-color: #f6bf9d;
#   color: #000000;
# }
# ...

# %%
# Out:
# <style type="text/css">
# #T_d64f5_row0_col2, #T_d64f5_row2_col3, #T_d64f5_row3_col4, #T_d64f5_row3_col5, #T_d64f5_row7_col4, #T_d64f5_row7_col5, #T_d64f5_row8_col4, #T_d64f5_row8_col5, #T_d64f5_row9_col4, #T_d64f5_row9_col5 {
#   background-color: #faebdd;
#   color: #000000;
# }
# #T_d64f5_row0_col3 {
#   background-color: #130d25;
#   color: #f1f1f1;
# }
# #T_d64f5_row0_col4, #T_d64f5_row0_col5, #T_d64f5_row1_col4, #T_d64f5_row1_col5 {
#   background-color: #f9e5d4;
#   color: #000000;
# }
# #T_d64f5_row1_col2, #T_d64f5_row3_col3 {
#   background-color: #04051a;
#   color: #f1f1f1;
# }
# #T_d64f5_row1_col3 {
#   background-color: #140e26;
#   color: #f1f1f1;
# }
# #T_d64f5_row2_col2 {
#   background-color: #1b112b;
#   color: #f1f1f1;
# }
# #T_d64f5_row2_col4, #T_d64f5_row2_col5, #T_d64f5_row3_col2, #T_d64f5_row8_col3 {
#   background-color: #03051a;
#   color: #f1f1f1;
# }
# #T_d64f5_row4_col2, #T_d64f5_row10_col2 {
#   background-color: #f7c9aa;
#   color: #000000;
# }
# ...

# %%
# Out:
# <style type="text/css">
# #T_7ccff_row0_col2, #T_7ccff_row4_col2, #T_7ccff_row4_col3, #T_7ccff_row5_col4, #T_7ccff_row5_col5 {
#   background-color: #faebdd;
#   color: #000000;
# }
# #T_7ccff_row0_col3 {
#   background-color: #f6a077;
#   color: #000000;
# }
# #T_7ccff_row0_col4, #T_7ccff_row0_col5 {
#   background-color: #08081e;
#   color: #f1f1f1;
# }
# #T_7ccff_row1_col2 {
#   background-color: #f7d0b5;
#   color: #000000;
# }
# #T_7ccff_row1_col3 {
#   background-color: #f5976e;
#   color: #000000;
# }
# #T_7ccff_row1_col4, #T_7ccff_row1_col5 {
#   background-color: #241432;
#   color: #f1f1f1;
# }
# #T_7ccff_row2_col2, #T_7ccff_row3_col2 {
#   background-color: #e13342;
#   color: #f1f1f1;
# }
# #T_7ccff_row2_col3 {
#   background-color: #c41753;
#   color: #f1f1f1;
# }
# #T_7ccff_row2_col4, #T_7ccff_row2_col5 {
#   background-color: #ba1656;
#   color: #f1f1f1;
# }
# #T_7ccff_row3_col3 {
#   background-color: #d82748;
#   color: #f1f1f1;
# }
# ...

# %%
# Out:
# <style type="text/css">
# #T_dcde2_row0_col1, #T_dcde2_row0_col2, #T_dcde2_row1_col1, #T_dcde2_row2_col3 {
#   background-color: #03051a;
#   color: #f1f1f1;
# }
# #T_dcde2_row0_col3 {
#   background-color: #841e5a;
#   color: #f1f1f1;
# }
# #T_dcde2_row1_col2, #T_dcde2_row1_col3, #T_dcde2_row2_col1, #T_dcde2_row2_col2 {
#   background-color: #faebdd;
#   color: #000000;
# }
# </style>
# <table id="T_dcde2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcde2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dcde2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_dcde2_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_dcde2_level0_col3" class="col_heading level0 col3" >R2 score</th>
#       <th id="T_dcde2_level0_col4" class="col_heading level0 col4" >Target variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
